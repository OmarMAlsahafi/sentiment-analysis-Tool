# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('G:\My Drive\Coding\Personal Projects\pandas_practice\sp500.csv',parse_dates=True,index_col='Date')

# %%
df.head(5)
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
#
#               Adj Close
# Date
# 2015-01-02  2058.199951
# 2015-01-05  2020.579956
# 2015-01-06  2002.609985
# 2015-01-07  2025.900024
# 2015-01-08  2062.139893

# %%
plt.plot(df['Adj Close'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2015-01-02 to 2015-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       252 non-null    float64
#  1   High       252 non-null    float64
#  2   Low        252 non-null    float64
#  3   Close      252 non-null    float64
#  4   Volume     252 non-null    int64
#  5   Adj Close  252 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
df.loc['2015-01-02']
# Out:
# Open         2.058900e+03
# High         2.072360e+03
# Low          2.046040e+03
# Close        2.058200e+03
# Volume       2.708700e+09
# Adj Close    2.058200e+03
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
df.loc['2015-01','Open':'Volume']
# Out:
#                    Open         High          Low        Close      Volume
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
# 2015-01-09  2063.449951  2064.429932  2038.329956  2044.810059  3364140000
# 2015-01-12  2046.130005  2049.300049  2022.579956  2028.260010  3456460000
# 2015-01-13  2031.579956  2056.929932  2008.250000  2023.030029  4107300000
# 2015-01-14  2018.400024  2018.400024  1988.439941  2011.270020  4378680000
# 2015-01-15  2013.750000  2021.349976  1991.469971  1992.670044  4276720000
# 2015-01-16  1992.250000  2020.459961  1988.119995  2019.420044  4056410000
# ...

# %%
df.loc['2015-01':'2015-04']
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
# ...                 ...          ...          ...          ...         ...
# 2015-04-24  2112.800049  2120.919922  2112.800049  2117.689941  3375780000
# 2015-04-27  2119.290039  2125.919922  2107.040039  2108.919922  3438750000
# 2015-04-28  2108.350098  2116.040039  2094.889893  2114.760010  3546270000
# 2015-04-29  2112.489990  2113.649902  2097.409912  2106.850098  4074970000
# 2015-04-30  2105.520020  2105.520020  2077.590088  2085.510010  4509680000
#
#               Adj Close
# Date
# 2015-01-02  2058.199951
# ...

# %%
nov = pd.to_datetime(['2015-2','2015-2'])

# %%
print(nov)
# Out:
# DatetimeIndex(['2015-02-01', '2015-02-01'], dtype='datetime64[ns]', freq=None)

# %%
df.loc['2015-02']
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-02-02  1996.670044  2021.660034  1980.900024  2020.849976  4008330000
# 2015-02-03  2022.709961  2050.300049  2022.709961  2050.030029  4615900000
# 2015-02-04  2048.860107  2054.739990  2036.719971  2041.510010  4141920000
# 2015-02-05  2043.449951  2063.550049  2043.449951  2062.520020  3821990000
# 2015-02-06  2062.280029  2072.399902  2049.969971  2055.469971  4232970000
# 2015-02-09  2053.469971  2056.159912  2041.880005  2046.739990  3549540000
# 2015-02-10  2049.379883  2070.860107  2048.620117  2068.590088  3669850000
# 2015-02-11  2068.550049  2073.479980  2057.989990  2068.530029  3596860000
# 2015-02-12  2069.979980  2088.530029  2069.979980  2088.479980  3788350000
# 2015-02-13  2088.780029  2097.030029  2086.699951  2096.989990  3527450000
# 2015-02-17  2096.469971  2101.300049  2089.800049  2100.340088  3361750000
# ...

# %%
df.reindex(nov,method='ffill')
# Out:
#                    Open         High          Low       Close      Volume  \
# 2015-02-01  2019.349976  2023.319946  1993.380005  1994.98999  4538650000
# 2015-02-01  2019.349976  2023.319946  1993.380005  1994.98999  4538650000
#
#              Adj Close
# 2015-02-01  1994.98999
# 2015-02-01  1994.98999

# %%
df.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
#
#               Adj Close
# Date
# 2015-01-02  2058.199951
# 2015-01-05  2020.579956
# 2015-01-06  2002.609985
# 2015-01-07  2025.900024
# 2015-01-08  2062.139893

# %%
stock = pd.read_csv('G:\My Drive\Coding\Personal Projects\pandas_practice\sp500.csv',parse_dates=True,index_col='Date')

# %%
stock.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
#
#               Adj Close
# Date
# 2015-01-02  2058.199951
# 2015-01-05  2020.579956
# 2015-01-06  2002.609985
# 2015-01-07  2025.900024
# 2015-01-08  2062.139893

# %%
daily_mean = stock.resample('D').mean()

# %%
monthly_mean=stock.resample('M').mean()

# %%
monthly_mean.loc['2015-1':'2015-12']
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2015-01-31  2031.392981  2043.618506  2013.377496  2028.178510  3.865002e+09
# 2015-02-28  2076.614727  2086.168952  2069.651046  2082.195794  3.619766e+09
# 2015-03-31  2081.527283  2090.509988  2070.099559  2079.990440  3.485266e+09
# 2015-04-30  2094.028123  2102.731887  2085.031448  2094.862840  3.306711e+09
# 2015-05-31  2111.099500  2119.614966  2103.135986  2111.943518  3.259386e+09
# 2015-06-30  2101.394542  2109.400446  2092.077282  2099.283658  3.327908e+09
# 2015-07-31  2092.989546  2102.516823  2083.964084  2094.143627  3.541845e+09
# 2015-08-31  2045.928089  2058.501907  2024.972389  2039.866205  4.029847e+09
# 2015-09-30  1947.264294  1962.428112  1929.715710  1944.402384  3.809018e+09
# 2015-10-31  2017.939547  2030.578647  2009.497725  2024.812716  3.902041e+09
# 2015-11-30  2080.275989  2089.545514  2070.572992  2080.616504  3.795680e+09
# ...

# %%
daily_mean.head(100)
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2.708700e+09
# 2015-01-03          NaN          NaN          NaN          NaN           NaN
# 2015-01-04          NaN          NaN          NaN          NaN           NaN
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3.799120e+09
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4.460110e+09
# ...                 ...          ...          ...          ...           ...
# 2015-04-07  2080.790039  2089.810059  2076.100098  2076.330078  3.065510e+09
# 2015-04-08  2076.939941  2086.689941  2073.300049  2081.899902  3.265330e+09
# 2015-04-09  2081.290039  2093.310059  2074.290039  2091.179932  3.172360e+09
# 2015-04-10  2091.510010  2102.610107  2091.510010  2102.060059  5.362000e+08
# 2015-04-11          NaN          NaN          NaN          NaN           NaN
#
#               Adj Close
# Date
# ...

# %%
daily_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 364 entries, 2015-01-02 to 2015-12-31
# Freq: D
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       252 non-null    float64
#  1   High       252 non-null    float64
#  2   Low        252 non-null    float64
#  3   Close      252 non-null    float64
#  4   Volume     252 non-null    float64
#  5   Adj Close  252 non-null    float64
# dtypes: float64(6)
# memory usage: 19.9 KB

# %%
daily_mean.reindex(method='ffill')
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2.708700e+09
# 2015-01-03          NaN          NaN          NaN          NaN           NaN
# 2015-01-04          NaN          NaN          NaN          NaN           NaN
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3.799120e+09
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4.460110e+09
# ...                 ...          ...          ...          ...           ...
# 2015-12-27          NaN          NaN          NaN          NaN           NaN
# 2015-12-28  2057.770020  2057.770020  2044.199951  2056.500000  2.492510e+09
# 2015-12-29  2060.540039  2081.560059  2060.540039  2078.360107  2.542000e+09
# 2015-12-30  2077.340088  2077.340088  2061.969971  2063.360107  2.367430e+09
# 2015-12-31  2060.590088  2062.540039  2043.619995  2043.939941  2.655330e+09
#
#               Adj Close
# Date
# ...

# %%
daily_mean = stock.resample('W').count()
daily_mean.head()
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 2015-01-04     1     1    1      1       1          1
# 2015-01-11     5     5    5      5       5          5
# 2015-01-18     5     5    5      5       5          5
# 2015-01-25     4     4    4      4       4          4
# 2015-02-01     5     5    5      5       5          5

# %%
print(daily_mean)
# Out:
#             Open  High  Low  Close  Volume  Adj Close
# Date
# 2015-01-04     1     1    1      1       1          1
# 2015-01-11     5     5    5      5       5          5
# 2015-01-18     5     5    5      5       5          5
# 2015-01-25     4     4    4      4       4          4
# 2015-02-01     5     5    5      5       5          5
# 2015-02-08     5     5    5      5       5          5
# 2015-02-15     5     5    5      5       5          5
# 2015-02-22     4     4    4      4       4          4
# 2015-03-01     5     5    5      5       5          5
# 2015-03-08     5     5    5      5       5          5
# 2015-03-15     5     5    5      5       5          5
# 2015-03-22     5     5    5      5       5          5
# 2015-03-29     5     5    5      5       5          5
# 2015-04-05     4     4    4      4       4          4
# 2015-04-12     5     5    5      5       5          5
# 2015-04-19     5     5    5      5       5          5
# ...

# %%
df.loc[:,"Volume"].resample('2W').sum()
two_months = df.loc['2015-1':'2015-2','Volume']

# %%
two_days=df.resample('2D').ffill()

# %%
two_days
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-04  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
# 2015-01-10  2063.449951  2064.429932  2038.329956  2044.810059  3364140000
# ...                 ...          ...          ...          ...         ...
# 2015-12-22  2023.150024  2042.739990  2020.489990  2038.969971  3520860000
# 2015-12-24  2063.520020  2067.360107  2058.729980  2060.989990  1411860000
# 2015-12-26  2063.520020  2067.360107  2058.729980  2060.989990  1411860000
# 2015-12-28  2057.770020  2057.770020  2044.199951  2056.500000  2492510000
# 2015-12-30  2077.340088  2077.340088  2061.969971  2063.360107  2367430000
#
#               Adj Close
# Date
# 2015-01-02  2058.199951
# ...

# %%
df.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
#
#               Adj Close
# Date
# 2015-01-02  2058.199951
# 2015-01-05  2020.579956
# 2015-01-06  2002.609985
# 2015-01-07  2025.900024
# 2015-01-08  2062.139893

# %%
df = pd.read_csv('G:\My Drive\Coding\Personal Projects\pandas_practice\sp500.csv',parse_dates=['Date'])

# %%
df.head()
# Out:
#         Date         Open         High          Low        Close      Volume  \
# 0 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 1 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 3 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 4 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
#
#      Adj Close
# 0  2058.199951
# 1  2020.579956
# 2  2002.609985
# 3  2025.900024
# 4  2062.139893

# %%
type(df['Date'].dt.month)
# Out:
# pandas.core.series.Series

# %%
central = df['Date'].dt.tz_localize('US/Central')

# %%
central.dt.tz_convert('US/Eastern')
# Out:
# 0     2015-01-02 01:00:00-05:00
# 1     2015-01-05 01:00:00-05:00
# 2     2015-01-06 01:00:00-05:00
# 3     2015-01-07 01:00:00-05:00
# 4     2015-01-08 01:00:00-05:00
#                  ...
# 247   2015-12-24 01:00:00-05:00
# 248   2015-12-28 01:00:00-05:00
# 249   2015-12-29 01:00:00-05:00
# 250   2015-12-30 01:00:00-05:00
# 251   2015-12-31 01:00:00-05:00
# Name: Date, Length: 252, dtype: datetime64[ns, US/Eastern]

# %%
population = pd.read_csv('G:\My Drive\Coding\Personal Projects\pandas_practice\WPP2022_Demographic_Indicators_Medium.csv')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17548\813454076.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   population = pd.read_csv('G:\My Drive\Coding\Personal Projects\pandas_practice\WPP2022_Demographic_Indicators_Medium.csv')

# %%
population.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  ...  Q0060Male Q0060Female     Q1550  \
# 0       World         0    World  ...   580.7496    498.0396  240.3164
# 1       World         0    World  ...   566.7283    490.1993  231.1772
# 2       World         0    World  ...   546.3173    477.2639  218.6745
# 3       World         0    World  ...   535.8289    469.5325  212.8720
# 4       World         0    World  ...   523.1236    458.4842  205.7622
#
#    Q1550Male  Q1550Female     Q1560  Q1560Male  Q1560Female  NetMigrations  \
# ...

# %%
sp500 = pd.read_csv('G:\My Drive\Coding\Personal Projects\pandas_practice\WPP2022_Demographic_Indicators_Medium.csv',parse_dates=True,index_col='Date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 sp500 = pd.read_csv('G:\My Drive\Coding\Personal Projects\pandas_practice\WPP2022_Demographic_Indicators_Medium.csv',parse_dates=True,index_col='Date')
#
# ...

# %%
sp500 = pd.read_csv('G:\My Drive\Coding\Personal Projects\pandas_practice\sp500.csv',parse_dates=True,index_col='Date')

# %%
sp500.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
#
#               Adj Close
# Date
# 2015-01-02  2058.199951
# 2015-01-05  2020.579956
# 2015-01-06  2002.609985
# 2015-01-07  2025.900024
# 2015-01-08  2062.139893

# %%
sp500.loc['2015-1','Close'].plot(title='S&P500',
                                              xlabel='date',
                                              style='+-k')
# Out:
# <Axes: title={'center': 'S&P500'}, xlabel='date'>

# %%
sp500.loc[:,'Close'].plot(title='S&P500',
                                              xlabel='date',
                                              style='+-k',
                                              kind='area')
# Out:
# <Axes: title={'center': 'S&P500'}, xlabel='date'>

# %%
sp500.loc[:,['Close','Open']].plot(title='S&P500',kind='line',color='k',
                                   subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951
# 1   2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956
# 2   2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985
# 3   2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024
# 4   2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893
# ..         ...          ...          ...          ...          ...
# 247 2015-12-24  2063.520020  2067.360107  2058.729980  2060.989990
# 248 2015-12-28  2057.770020  2057.770020  2044.199951  2056.500000
# 249 2015-12-29  2060.540039  2081.560059  2060.540039  2078.360107
# 250 2015-12-30  2077.340088  2077.340088  2061.969971  2063.360107
# 251 2015-12-31  2060.590088  2062.540039  2043.619995  2043.939941
#
#          Volume    Adj Close
# 0    2708700000  2058.199951
# 1    3799120000  2020.579956
# 2    4460110000  2002.609985
# 3    3805480000  2025.900024
# ...

# %%
more_than_2050=df[df.Open>2050]

# %%
df2 = df.copy()

# %%
type(df2[['Open','Close']])
# Out:
# pandas.core.frame.DataFrame
